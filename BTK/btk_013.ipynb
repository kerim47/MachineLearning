# %%
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense

# %%
# ilkleme
classifier = Sequential()
classifier.add(Convolution2D(32, 3, 3, input_shape= (64, 64, 3), activation= 'relu'))
classifier.add(MaxPooling2D(pool_size=(2, 2)))
classifier.add(Convolution2D(32, 3, 3, activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2, 2)))
classifier.add(Dense(units=128, activation ='relu'))
classifier.add(Dense(units=1, activation='sigmoid'))
classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# /home/kerim/anaconda3/envs/MachineLearning/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255,
                                  shear_range=0.2,
                                  zoom_range=0.2,
                                  horizontal_flip=True)

training_set = train_datagen.flow_from_directory('veriler/training_set', 
                                                 target_size=(64, 64), 
                                                 batch_size=1, 
                                                 class_mode='binary')

test_set = test_datagen.flow_from_directory('veriler/test_set', 
                                           target_size=(64, 64), 
                                           batch_size=1, 
                                           class_mode='binary')

# classifier.fit(training_set, steps_per_epoch=8000, epochs=1, validation_data=test_set, validation_steps=2000)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from tensorflow.keras.preprocessing.image import ImageDataGenerator
#       3 train_datagen = ImageDataGenerator(rescale=1./255,
#       4                                    shear_range=0.2,
#       5                                    zoom_range=0.2,
#       6                                    horizontal_flip=True)
#       8 test_datagen = ImageDataGenerator(rescale=1./255,
#       9                                   shear_range=0.2,
#      10                                   zoom_range=0.2,
#      11                                   horizontal_flip=True)
#
# File ~/anaconda3/envs/MachineLearning/lib/python3.11/site-packages/keras/api/_v2/keras/__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.api._v2.keras import __internal__
#       4 from keras.api._v2.keras import activations
#       5 from keras.api._v2.keras import applications
#
# File ~/anaconda3/envs/MachineLearning/lib/python3.11/site-packages/keras/api/_v2/keras/__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.api._v2.keras import __internal__
#       4 from keras.api._v2.keras import activations
#       5 from keras.api._v2.keras import applications
#
# File ~/anaconda3/envs/MachineLearning/lib/python3.11/site-packages/keras/api/_v2/keras/__internal__/__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.api._v2.keras.__internal__ import backend
#       4 from keras.api._v2.keras.__internal__ import layers
#       5 from keras.api._v2.keras.__internal__ import losses
#
# File ~/anaconda3/envs/MachineLearning/lib/python3.11/site-packages/keras/api/_v2/keras/__internal__/backend/__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.src.backend import _initialize_variables as initialize_variables
#       4 from keras.src.backend import track_variable
#
# ImportError: cannot import name '_initialize_variables' from 'keras.src.backend' (/home/kerim/anaconda3/envs/MachineLearning/lib/python3.11/site-packages/keras/src/backend/__init__.py)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Flatten, Dense
from keras.preprocessing.image import ImageDataGenerator

# Modeli başlat
classifier = Sequential()

# Adım 1 - Convolution
classifier.add(Conv2D(32, (3, 3), input_shape=(64, 64, 3), activation='relu'))

# Adım 2 - Pooling
classifier.add(MaxPooling2D(pool_size=(2, 2)))

# 2. convolution katmanı
classifier.add(Conv2D(32, (3, 3), activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2, 2)))

# Adım 3 - Flattening
classifier.add(Flatten())

# Adım 4 - YSA
classifier.add(Dense(units=128, activation='relu'))
classifier.add(Dense(units=1, activation='sigmoid'))

# Modeli derle
classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Eğitim ve test verilerini hazırla
train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

training_set = train_datagen.flow_from_directory('veriler/training_set',
                                                 target_size=(64, 64),
                                                 batch_size=32,
                                                 class_mode='binary')

test_set = test_datagen.flow_from_directory('veriler/test_set',
                                            target_size=(64, 64),
                                            batch_size=32,
                                            class_mode='binary')

# Modeli eğit
classifier.fit_generator(training_set, steps_per_epoch=len(training_set), epochs=25, validation_data=test_set, validation_steps=len(test_set))

# Tahminleri al
test_set.reset()
pred = classifier.predict_generator(test_set, verbose=1)
pred[pred > 0.5] = 1
pred[pred <= 0.5] = 0

# Confusion matrix hesapla
from sklearn.metrics import confusion_matrix
import numpy as np

test_labels = []

for i in range(len(test_set)):
    test_labels.extend(np.array(test_set[i][1]))

cm = confusion_matrix(test_labels, pred)
print(cm)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 4
#       2 from keras.layers import Conv2D, MaxPooling2D
#       3 from keras.layers import Flatten, Dense
# ----> 4 from keras.preprocessing.image import ImageDataGenerator
#       6 # Modeli başlat
#       7 classifier = Sequential()
#
# ImportError: cannot import name 'ImageDataGenerator' from 'keras.preprocessing.image' (/home/kerim/anaconda3/envs/MachineLearning/lib/python3.11/site-packages/keras/preprocessing/image/__init__.py)
